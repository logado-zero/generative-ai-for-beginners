# %% [markdown]
# The following notebook was auto-generated by GitHub Copilot Chat and is meant for initial setup only

# %% [markdown]
# # Advanced Prompt Engineering

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
load_dotenv()

client =  OpenAI(
  api_key=os.environ['OPENAI_API_KEY'],
  organization= os.environ['OPENAI_ORG'],
  project= os.environ['OPENAI_PROJECT'],
)

deployment = "gpt-3.5-turbo"
## Updated
def get_completion(prompt):
    messages = [{"role": "user", "content": prompt}]       
    response = client.chat.completions.create(   
        model=deployment,                                         
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
        max_tokens=1024
    )
    return response.choices[0].message.content

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
python
from flask import Flask, request

app = Flask(__name__)

@app.route('/')
def hello():
    name = request.args.get('name', 'World')
    return f'Hello, {{name}}!'

if __name__ == '__main__':
    app.run()

Question: suggest 3 improvements of the above code showing how to build a simple API using Flask
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# 1. Add error handling: It's important to handle errors in your API to provide meaningful responses to clients. You can use Flask's error handling decorators to handle different types of errors and return appropriate responses.
#
# ```python
# @app.errorhandler(404)
# def page_not_found(e):
#     return "404 Error: Page not found", 404
#
# @app.errorhandler(500)
# def internal_server_error(e):
#     return "500 Error: Internal Server Error", 500
# ```
#
# 2. Implement POST method: In addition to handling GET requests, you can also implement POST requests to allow clients to send data to your API. You can use the `request.json` attribute to access the JSON data sent in the request body.
#
# ```python
# @app.route('/post', methods=['POST'])
# def post_data():
#     data = request.json
#     return f'Received data: {data}'
# ```
#
# ...
